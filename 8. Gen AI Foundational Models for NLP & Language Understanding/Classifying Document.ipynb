# %%
# %pip install --upgrade torchtext
# Out:
# Requirement already satisfied: torchtext in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (0.18.0)
# Requirement already satisfied: tqdm in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torchtext) (2.8.0)
# Requirement already satisfied: numpy in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torchtext) (1.26.4)
# Requirement already satisfied: filelock in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torch>=2.3.0->torchtext) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torch>=2.3.0->torchtext) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torch>=2.3.0->torchtext) (1.14.0)
# Requirement already satisfied: networkx in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torch>=2.3.0->torchtext) (3.5)
# Requirement already satisfied: jinja2 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torch>=2.3.0->torchtext) (3.1.6)
# Requirement already satisfied: fsspec in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torch>=2.3.0->torchtext) (2025.7.0)
# Requirement already satisfied: setuptools in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from torch>=2.3.0->torchtext) (78.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from requests->torchtext) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from requests->torchtext) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from requests->torchtext) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from requests->torchtext) (2025.1.31)
# Requirement already satisfied: colorama in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from tqdm->torchtext) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from sympy>=1.13.3->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\github\ibm-ai-engineering-professional-certificate\.venv\lib\site-packages (from jinja2->torch>=2.3.0->torchtext) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
from itertools import accumulate
import matplotlib.pyplot as plt
import torchtext
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
# Out:
# D:\GitHub\IBM-AI-Engineering-Professional-Certificate\.venv\Lib\site-packages\torchtext\__init__.py:7: SyntaxWarning: invalid escape sequence '\ '
#   "\n/!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\ \n"
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 6
#       4 from itertools import accumulate
#       5 import matplotlib.pyplot as plt
# ----> 6 import torchtext
#       7 import torch
#       8 import torch.nn as nn
#
# File D:\GitHub\IBM-AI-Engineering-Professional-Certificate\.venv\Lib\site-packages\torchtext\__init__.py:18
#      15     _WARN = False
#      17 # the following import has to happen first in order to load the torchtext C++ library
# ---> 18 from torchtext import _extension  # noqa: F401
#      20 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      22 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
#
# File D:\GitHub\IBM-AI-Engineering-Professional-Certificate\.venv\Lib\site-packages\torchtext\_extension.py:64
#      59     # This import is for initializing the methods registered via PyBind11
#      60     # This has to happen after the base library is loaded
#      61     from torchtext import _torchtext  # noqa
# ---> 64 _init_extension()
#
# File D:\GitHub\IBM-AI-Engineering-Professional-Certificate\.venv\Lib\site-packages\torchtext\_extension.py:58, in _init_extension()
#      55 if not _mod_utils.is_module_available("torchtext._torchtext"):
#      56     raise ImportError("torchtext C++ Extension is not found.")
# ---> 58 _load_lib("libtorchtext")
#      59 # This import is for initializing the methods registered via PyBind11
#      60 # This has to happen after the base library is loaded
#      61 from torchtext import _torchtext
#
# File D:\GitHub\IBM-AI-Engineering-Professional-Certificate\.venv\Lib\site-packages\torchtext\_extension.py:50, in _load_lib(lib)
#      48 if not path.exists():
#      49     return False
# ---> 50 torch.ops.load_library(path)
#      51 return True
#
# File D:\GitHub\IBM-AI-Engineering-Professional-Certificate\.venv\Lib\site-packages\torch\_ops.py:1478, in _Ops.load_library(self, path)
#    1473 path = _utils_internal.resolve_library_path(path)
#    1474 with dl_open_guard():
#    1475     # Import the shared library into the process, thus running its
#    1476     # static (global) initialization code in order to register custom
#    1477     # operators with the JIT.
# -> 1478     ctypes.CDLL(path)
#    1479 self.loaded_libraries.add(path)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ctypes\__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     376 self._FuncPtr = _FuncPtr
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#     381     self._handle = handle
#
# OSError: [WinError 127] The specified procedure could not be found
