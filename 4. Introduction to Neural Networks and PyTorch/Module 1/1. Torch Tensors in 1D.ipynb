# %%
import torch
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.8.0+cpu'

# %%
def plotVec(vectors):
    ax = plt.axes()

    # For loop to draw the vectors
    for vec in vectors:
        ax.arrow(0, 0, *vec["vector"], head_width = 0.05,color = vec["color"], head_length = 0.1)
        plt.text(*(vec["vector"] + 0.1), vec["name"])

    plt.ylim(-2,2)
    plt.xlim(-2,2)

# %%
ints_to_tensor = torch.tensor([0, 1, 2, 3, 4])

print(ints_to_tensor.dtype)
print(ints_to_tensor.type())
print(type(ints_to_tensor))
# Out:
# torch.int64
# torch.LongTensor
# <class 'torch.Tensor'>

# %%
floats_to_tensor = torch.tensor([0.0, 1.0, 2.0, 3.0, 4.0])
print(floats_to_tensor.dtype)
print(floats_to_tensor.type())
print(type(floats_to_tensor))
# Out:
# torch.float32
# torch.FloatTensor
# <class 'torch.Tensor'>

# %%
list_floats=[0.0, 1.0, 2.0, 3.0, 4.0]
floats_int_tensor = torch.tensor(list_floats, dtype=torch.int64)
print(floats_int_tensor.dtype)
print(floats_int_tensor.type())
# Out:
# torch.int64
# torch.LongTensor

# %%
new_float_tensor = torch.FloatTensor([0, 1, 2, 3, 4])
print(new_float_tensor.dtype)
print(new_float_tensor.type())
# Out:
# torch.float32
# torch.FloatTensor

# %%
old_int_tensor = torch.tensor([0, 1, 2, 3, 4])
new_float_tensor = old_int_tensor.type(torch.FloatTensor)

print(new_float_tensor.dtype)
print(new_float_tensor.type())
# Out:
# torch.float32
# torch.FloatTensor

# %%
print(new_float_tensor.size())
print(new_float_tensor.ndimension())
# Out:
# torch.Size([5])
# 1

# %%
twoD_float_tensor = new_float_tensor.view(5, 1)
print(twoD_float_tensor.size())
print(twoD_float_tensor.ndimension())
# Out:
# torch.Size([5, 1])
# 2

# %%
print(twoD_float_tensor)
# Out:
# tensor([[0.],
#         [1.],
#         [2.],
#         [3.],
#         [4.]])

# %%
twoD_float_tensor = new_float_tensor.view(-1, 1)
print(twoD_float_tensor.size())
print(twoD_float_tensor.ndimension())
# Out:
# torch.Size([5, 1])
# 2

# %%
numpy_array = np.array([0.0, 1.0, 2.0, 3.0, 4.0])
new_tensor = torch.from_numpy(numpy_array)
print(new_tensor.dtype)
print(new_tensor.type())
# Out:
# torch.float64
# torch.DoubleTensor

# %%
back_to_numpy = new_tensor.numpy()
print(back_to_numpy)
print(back_to_numpy.dtype)
# Out:
# [0. 1. 2. 3. 4.]
# float64

# %%
numpy_array[:] = 0
print(new_tensor)
print(back_to_numpy)
# Out:
# tensor([0., 0., 0., 0., 0.], dtype=torch.float64)
# [0. 0. 0. 0. 0.]

# %%
pandas_series=pd.Series([0.1, 2, 0.3, 10.1])
new_tensor=torch.from_numpy(pandas_series.values)
print(new_tensor)
print(new_tensor.dtype)
print(new_tensor.type())
# Out:
# tensor([ 0.1000,  2.0000,  0.3000, 10.1000], dtype=torch.float64)
# torch.float64
# torch.DoubleTensor

# %%
this_tensor=torch.tensor([0,1, 2,3])
print(this_tensor[0])
print(this_tensor[0].item())
# Out:
# tensor(0)
# 0

# %%
torch_to_list=this_tensor.tolist()
print(torch_to_list)
# Out:
# [0, 1, 2, 3]

# %%
your_tensor = torch.tensor([1, 2, 3, 4, 5])
new_tensor = your_tensor.view(1, 5)
print(your_tensor.size())
print(new_tensor.size())
# Out:
# torch.Size([5])
# torch.Size([1, 5])

# %%
index_tensor = torch.tensor([0, 1, 2, 3, 4])

print(index_tensor[0])
print(index_tensor[1])
print(index_tensor[2])
print(index_tensor[3])
print(index_tensor[4])
# Out:
# tensor(0)
# tensor(1)
# tensor(2)
# tensor(3)
# tensor(4)

# %%
index_tensor[0] = 100
print(index_tensor)
# Out:
# tensor([100,   1,   2,   3,   4])

# %%
print(index_tensor[0:2])
# Out:
# tensor([100,   1])

# %%
index_tensor[0:2] = torch.tensor([200, 300])
print(index_tensor)
# Out:
# tensor([200, 300,   2,   3,   4])

# %%
index_tensor[[0, 1]]
# Out:
# tensor([200, 300])

# %%
index_tensor[0:2]
# Out:
# tensor([200, 300])

# %%
index_tensor[0:2] = 10000
index_tensor
# Out:
# tensor([10000, 10000,     2,     3,     4])

# %%
practice_tensor = torch.tensor([2, 7, 3, 4, 6, 2, 3, 1, 2])
practice_tensor[[3, 4, 7]] = 0
print(practice_tensor)
# Out:
# tensor([2, 7, 3, 0, 0, 2, 3, 0, 2])

# %%
math_tensor = torch.tensor([1.0, -1.0, 1, -1])
print(math_tensor.mean())
print(math_tensor.std())
print(math_tensor.max())
print(math_tensor.min())
# Out:
# tensor(0.)
# tensor(1.1547)
# tensor(1.)
# tensor(-1.)

# %%
pi_tensor = torch.tensor([0, np.pi/2, np.pi])
print(torch.sin(pi_tensor))
# Out:
# tensor([ 0.0000e+00,  1.0000e+00, -8.7423e-08])

# %%
len_5_tensor = torch.linspace(-2, 2, steps = 10)
print(len_5_tensor)
# Out:
# tensor([-2.0000, -1.5556, -1.1111, -0.6667, -0.2222,  0.2222,  0.6667,  1.1111,
#          1.5556,  2.0000])

# %%
pi_tensor = torch.linspace(0, 2*np.pi, 100)
sin_result = torch.sin(pi_tensor)
plt.plot(pi_tensor.numpy(), sin_result.numpy())

# %%
pi_tensor = torch.linspace(0, np.pi/2, 100)
print("Max Number: ", pi_tensor.max())
print("Min Number", pi_tensor.min())
sin_result = torch.sin(pi_tensor)
plt.plot(pi_tensor.numpy(), sin_result.numpy())
# Out:
# Max Number:  tensor(1.5708)
# Min Number tensor(0.)

# %%
u = torch.tensor([1, 0])
v = torch.tensor([0, 1])

w = u + v
print(w)
# Out:
# tensor([1, 1])

# %%
plotVec([
    {"vector": u.numpy(), "name": 'u', "color": 'r'},
    {"vector": v.numpy(), "name": 'v', "color": 'b'},
    {"vector": w.numpy(), "name": 'w', "color": 'g'}
])

# %%
u = torch.tensor([1, 0])
v = torch.tensor([0, 1])
w = u-v
plotVec([
    {"vector": u.numpy(), "name": 'u', "color": 'r'},
    {"vector": v.numpy(), "name": 'v', "color": 'b'},
    {"vector": w.numpy(), "name": 'w', "color": 'g'}
])

# %%
torch.tensor([1,2,3],dtype=torch.int64)+torch.tensor([1,2,3],dtype=torch.float64)
# Out:
# tensor([2., 4., 6.], dtype=torch.float64)

# %%
u = torch.tensor([1, 2, 3, -1])
v = u + 1
print(v)
# Out:
# tensor([2, 3, 4, 0])

# %%
u = torch.tensor([1, 2])
v = 2 * u
print(v)
# Out:
# tensor([2, 4])

# %%
u = torch.tensor([1, 2])
v = torch.tensor([3, 2])
w = u * v
print(w)
# Out:
# tensor([3, 4])

# %%
u = torch.tensor([1, 2])
v = torch.tensor([3, 2])

print(torch.dot(u, v))
# Out:
# tensor(7)

# %%
u= torch.tensor([-1, 1])
v= torch.tensor([1, 1])
plotVec([
    {"vector": u.numpy(), "name": 'u', "color": 'r'},
    {"vector": v.numpy(), "name": 'v', "color": 'b'}
])

# %%
print(np.dot(u, v))
# Out:
# 0
