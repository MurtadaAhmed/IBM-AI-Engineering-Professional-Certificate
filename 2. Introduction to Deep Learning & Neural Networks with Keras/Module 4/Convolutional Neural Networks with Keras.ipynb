# %%
# supress the warning messages due to the usage of CPU:
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten
from keras.utils import to_categorical
from keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000,)
# (10000,)

# %%
# reshaping the dataset to make it ready as convolutional network by adding the dimension "1", as mnist dataset is grayscale
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
# convert the target variables into binary
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 10)
# (10000, 10)

# %%
num_classes = y_train.shape[1]
print(num_classes)
# Out:
# 10

# %%
def convolutional_model():
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    # 16: number of filters. (5,5): filter (kernel) size by pixels. (1, 1): how pixels the filter moves each time
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    # pool_size=(2, 2): takes the maximin values in each 2*2 region. strides=(2, 2): how many pixels the pooling window moves each time
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model = convolutional_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/10
# 300/300 - 7s - 24ms/step - accuracy: 0.9123 - loss: 1.1315 - val_accuracy: 0.9542 - val_loss: 0.2094
# Epoch 2/10
# 300/300 - 5s - 17ms/step - accuracy: 0.9718 - loss: 0.1095 - val_accuracy: 0.9693 - val_loss: 0.1275
# Epoch 3/10
# 300/300 - 6s - 19ms/step - accuracy: 0.9832 - loss: 0.0575 - val_accuracy: 0.9734 - val_loss: 0.1136
# Epoch 4/10
# 300/300 - 6s - 20ms/step - accuracy: 0.9894 - loss: 0.0333 - val_accuracy: 0.9764 - val_loss: 0.1007
# Epoch 5/10
# 300/300 - 5s - 18ms/step - accuracy: 0.9928 - loss: 0.0215 - val_accuracy: 0.9759 - val_loss: 0.1096
# Epoch 6/10
# 300/300 - 5s - 17ms/step - accuracy: 0.9949 - loss: 0.0150 - val_accuracy: 0.9778 - val_loss: 0.1030
# Epoch 7/10
# 300/300 - 4s - 14ms/step - accuracy: 0.9947 - loss: 0.0158 - val_accuracy: 0.9760 - val_loss: 0.1292
# Epoch 8/10
# 300/300 - 5s - 15ms/step - accuracy: 0.9945 - loss: 0.0167 - val_accuracy: 0.9787 - val_loss: 0.1211
# Epoch 9/10
# ...

# %%
scores = model.evaluate(X_test, y_test, verbose=0)

# %%
scores
# Out:
# [0.11993949115276337, 0.9775999784469604]

# %%
print(f"Accuracy: {scores[1]}")
# Out:
# Accuracy: 0.9775999784469604

# %%
print(f"Error: {100 - scores[1] * 100}")
# Out:
# Error: 2.240002155303955

# %%
def convolutional_model():
    model = Sequential()

    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
model = convolutional_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Out:
# Epoch 1/100
# 300/300 - 7s - 22ms/step - accuracy: 0.7794 - loss: 2.2307 - val_accuracy: 0.9171 - val_loss: 0.3231
# Epoch 2/100
# 300/300 - 5s - 18ms/step - accuracy: 0.9372 - loss: 0.2483 - val_accuracy: 0.9540 - val_loss: 0.1757
# Epoch 3/100
# 300/300 - 5s - 17ms/step - accuracy: 0.9585 - loss: 0.1523 - val_accuracy: 0.9656 - val_loss: 0.1222
# Epoch 4/100
# 300/300 - 5s - 18ms/step - accuracy: 0.9686 - loss: 0.1085 - val_accuracy: 0.9721 - val_loss: 0.1007
# Epoch 5/100
# 300/300 - 5s - 17ms/step - accuracy: 0.9754 - loss: 0.0830 - val_accuracy: 0.9718 - val_loss: 0.0945
# Epoch 6/100
# 300/300 - 6s - 19ms/step - accuracy: 0.9790 - loss: 0.0695 - val_accuracy: 0.9753 - val_loss: 0.0873
# Epoch 7/100
# 300/300 - 5s - 18ms/step - accuracy: 0.9820 - loss: 0.0578 - val_accuracy: 0.9781 - val_loss: 0.0754
# Epoch 8/100
# 300/300 - 6s - 18ms/step - accuracy: 0.9841 - loss: 0.0514 - val_accuracy: 0.9811 - val_loss: 0.0644
# Epoch 9/100
# ...

# %%
scores = model.evaluate(X_test, y_test, verbose=0)

# %%
scores
# Out:
# [0.1613926887512207, 0.9882000088691711]

# %%
print(f"Accuracy: {scores[1]}")
# Out:
# Accuracy: 0.9882000088691711

# %%
print(f"Error: {100 - scores[1] * 100}")
# Out:
# Error: 1.1799991130828857

# %%
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 6s - 100ms/step - accuracy: 0.4921 - loss: 7.0163 - val_accuracy: 0.7115 - val_loss: 1.3254
# Epoch 2/10
# 59/59 - 5s - 77ms/step - accuracy: 0.7888 - loss: 0.9311 - val_accuracy: 0.8600 - val_loss: 0.6018
# Epoch 3/10
# 59/59 - 5s - 78ms/step - accuracy: 0.8785 - loss: 0.5129 - val_accuracy: 0.9025 - val_loss: 0.4078
# Epoch 4/10
# 59/59 - 5s - 79ms/step - accuracy: 0.9117 - loss: 0.3615 - val_accuracy: 0.9239 - val_loss: 0.3138
# Epoch 5/10
# 59/59 - 5s - 76ms/step - accuracy: 0.9295 - loss: 0.2769 - val_accuracy: 0.9373 - val_loss: 0.2549
# Epoch 6/10
# 59/59 - 5s - 79ms/step - accuracy: 0.9418 - loss: 0.2250 - val_accuracy: 0.9437 - val_loss: 0.2169
# Epoch 7/10
# 59/59 - 4s - 76ms/step - accuracy: 0.9507 - loss: 0.1862 - val_accuracy: 0.9521 - val_loss: 0.1868
# Epoch 8/10
# 59/59 - 4s - 76ms/step - accuracy: 0.9564 - loss: 0.1600 - val_accuracy: 0.9556 - val_loss: 0.1700
# Epoch 9/10
# ...

# %%
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 6s - 93ms/step - accuracy: 0.5476 - loss: 5.1910 - val_accuracy: 0.7975 - val_loss: 0.8636
# Epoch 2/25
# 59/59 - 4s - 75ms/step - accuracy: 0.8427 - loss: 0.6382 - val_accuracy: 0.8896 - val_loss: 0.4470
# Epoch 3/25
# 59/59 - 5s - 81ms/step - accuracy: 0.9020 - loss: 0.3806 - val_accuracy: 0.9212 - val_loss: 0.3170
# Epoch 4/25
# 59/59 - 5s - 77ms/step - accuracy: 0.9255 - loss: 0.2744 - val_accuracy: 0.9362 - val_loss: 0.2541
# Epoch 5/25
# 59/59 - 5s - 78ms/step - accuracy: 0.9409 - loss: 0.2143 - val_accuracy: 0.9448 - val_loss: 0.2151
# Epoch 6/25
# 59/59 - 5s - 77ms/step - accuracy: 0.9513 - loss: 0.1760 - val_accuracy: 0.9485 - val_loss: 0.1922
# Epoch 7/25
# 59/59 - 5s - 87ms/step - accuracy: 0.9581 - loss: 0.1494 - val_accuracy: 0.9548 - val_loss: 0.1711
# Epoch 8/25
# 59/59 - 5s - 79ms/step - accuracy: 0.9625 - loss: 0.1313 - val_accuracy: 0.9576 - val_loss: 0.1587
# Epoch 9/25
# ...
