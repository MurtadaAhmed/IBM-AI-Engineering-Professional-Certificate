# %%
# !pip install Levenshtein
# Out:
# Collecting Levenshtein
#   Obtaining dependency information for Levenshtein from https://files.pythonhosted.org/packages/2c/a6/907a1fc8587dc91c40156973e09d106ab064c06eb28dc4700ba0fe54d654/levenshtein-0.27.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading levenshtein-0.27.3-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein)
#   Obtaining dependency information for rapidfuzz<4.0.0,>=3.9.0 from https://files.pythonhosted.org/packages/b8/63/d06ecce90e2cf1747e29aeab9f823d21e5877a4c51b79720b2d3be7848f8/rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Downloading levenshtein-0.27.3-cp312-cp312-win_amd64.whl (94 kB)
#    ---------------------------------------- 0.0/94.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/94.9 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/94.9 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/94.9 kB 262.6 kB/s eta 0:00:01
#    ----------------- ---------------------- 41.0/94.9 kB 245.8 kB/s eta 0:00:01
#    ------------------------- -------------- 61.4/94.9 kB 297.7 kB/s eta 0:00:01
#    ---------------------------------------- 94.9/94.9 kB 386.6 kB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.5 MB 1.9 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.5 MB 1.5 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.5 MB 1.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.5 MB 1.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.5 MB 1.3 MB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.5 MB 1.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.5 MB 1.6 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.5 MB 1.6 MB/s eta 0:00:01
#    ------------------ --------------------- 0.7/1.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.5 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.27.3 rapidfuzz-3.14.3
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import sys
import time
import warnings
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import requests
from Levenshtein import distance
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
split = 'train'
learning_rate = 3e-4
batch_size = 64
max_iters = 5000
eval_interval = 200
eval_iters = 100

max_vocab_size = 265
vocab_size = max_vocab_size
block_size = 16
n_embd = 32
num_heads = 2
n_layer = 2
ff_scale_factor = 4
dropout = 0.0

head_size = n_embd // num_heads
assert (num_heads * head_size) == n_embd

# %%
# Out:
# True
